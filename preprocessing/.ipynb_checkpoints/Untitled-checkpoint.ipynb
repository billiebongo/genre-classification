# %%
import pandas as pd
import numpy as np

import sys
print(sys.version)

from sklearn.feature_extraction.text import CountVectorizer

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re


import pickle 
#import mglearn
import time


from nltk.tokenize import TweetTokenizer # doesn't split at apostrophes
from nltk import Text
from nltk.tokenize import regexp_tokenize
from nltk.tokenize import word_tokenize  

from nltk.tokenize import sent_tokenize 
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer


from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression 
from sklearn.naive_bayes import MultinomialNB
from sklearn.multiclass import OneVsRestClassifier


from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline

from clean_data import clean_description as clean_des
# Out:
# 3.6.5 |Anaconda, Inc.| (default, Apr 29 2018, 16:14:56)
# [GCC 7.2.0]

# %%
df = pd.read_csv('../preprocessing/data.csv', sep='\t')
print("***DATA INFORMATION***")
print("DISTRIBUTION")
print(df.groupby(['genre']).count()["id"])
print(df["genre"].unique())
print(df["genre"].describe())
print(df.shape)
df.head()
# Out:
# ***DATA INFORMATION***
# DISTRIBUTION
# genre
# 1                       1
# 1999                    1
# 2005                    1
# Science-fiction         1
# Self-help               1
# adventure             257
# art                    76
# biography            1188
# biology                 5
# business              310
# chick-lit             313
# children             1787
# comics                207
# computer-science        1
# cookbook              137
# drama                 255
# economics              68
# entrepreneurship        1
# fantasy              4098
# fiction              5433
# finance                34
# gr                     42
# health                117
# historical            714
# history               892
# horror                637
# humour                201
# math                   53
# mystery              2659
# nil                 15536
# non-fiction          2764
# philosophy            196
# physics                 1
# politics              290
# psychology            186
# religion              550
# romance              2063
# science               420
# science-fiction       193
# scifi                  36
# scifi3                  1
# self-help             163
# social-science         12
# thriller              608
# travel                264
# young-adult          2964
# Name: id, dtype: int64
# ['non-fiction' 'fantasy' 'young-adult' 'mystery' 'romance' 'fiction'
#  'horror' 'children' 'thriller' 'nil' 'business' 'economics' 'cookbook'
#  'art' 'biography' 'travel' 'science' 'politics' 'history' 'adventure'
#  'Science-fiction' 'chick-lit' 'Self-help' 'historical' 'math' 'humour'
#  'philosophy' 'psychology' 'scifi' 'drama' 'religion' 'health' 'self-help'
#  'scifi3' 'gr' 'comics' 'physics' 'finance' '1999' '2005' '1'
#  'computer-science' 'biology' 'social-science' 'science-fiction'
#  'entrepreneurship']
# count     45737
# unique       46
# top         nil
# freq      15536
# Name: genre, dtype: object
# (45737, 8)
#    id                                         book_title  \
# 0  89  Factfulness: Ten Reasons We're Wrong About the...
# 1  90                       Magic, Madness, and Mischief
# 2  91                         Spirits, Spells, and Snark
# 3  92  First Kisses and Other Misfortunes (Grimbaud, ...
# 4  93  Law School Confidential: A Complete Guide to t...
#
#                                              authors  \
# 0  [Hans Rosling, Anna Rosling Rönnlund, Ola Rosl...
# 1                                 [Kelly McCullough]
# 2                                 [Kelly McCullough]
# 3                                [Kimberly Karalius]
# 4                              [Robert H.    Miller]
#
#                                                cover pub_year src  \
# 0  https://images.gr-assets.com/books/1515081996l...     2018  gr
# 1  https://images.gr-assets.com/books/1495611091l...     2018  gr
# 2  https://images.gr-assets.com/books/1527371743l...     2019  gr
# 3  https://images.gr-assets.com/books/1453682215l...     2016  gr
# 4  https://images.gr-assets.com/books/1446487725l...     2015  gr
#
#          genre                                        description
# 0  non-fiction  Factfulness: The stress-reducing habit of only...
# 1      fantasy  "A 12-year-old boy uses his new magical powers...
# 2      fantasy  Kalvan Monroe is worried. Every story he's eve...
# 3  young-adult  In Kimberly Karalius's First Kisses and Other ...
# 4  non-fiction  I WISH I KNEW THEN WHAT I KNOW NOW!\n\nDon't g...

# %%
print("Fixing dirty data")
# strange genres


df.genre[df.genre=="scifi3"] = "science-fiction"
df.genre[df.genre=="Science-fiction"] = "science-fiction"
df[df["genre"]=="Science-fiction"]["genre"]="science-fiction"

df[df["genre"]=="scifi"]["genre"]="science-fiction"
print("************")

df = df[df.genre != "1999"]
df = df[df.genre != "2005"]
print(df.groupby(['genre']).count()["id"])
# Out:
# Fixing dirty data
# ************
# genre
# 1                       1
# Science-fiction         1
# Self-help               1
# adventure             257
# art                    76
# biography            1188
# biology                 5
# business              310
# chick-lit             313
# children             1787
# comics                207
# computer-science        1
# cookbook              137
# drama                 255
# economics              68
# entrepreneurship        1
# fantasy              4098
# fiction              5433
# finance                34
# gr                     42
# health                117
# historical            714
# history               892
# horror                637
# humour                201
# math                   53
# mystery              2659
# nil                 15536
# non-fiction          2764
# philosophy            196
# physics                 1
# politics              290
# psychology            186
# religion              550
# romance              2063
# science               420
# science-fiction       194
# scifi                  36
# self-help             163
# social-science         12
# thriller              608
# travel                264
# young-adult          2964
# Name: id, dtype: int64
# /home/sloth/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/sloth/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/sloth/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
